# %% [markdown]
# # Data Exploration
# Load the system metrics dataset and inspect its columns and summary statistics.

# %%
import pandas as pd

df = pd.read_csv('../datasets/system_metrics_sample.csv')
df.head()

# %%
df.describe()
