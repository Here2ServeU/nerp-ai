# %% [markdown]
# # Prediction Demo
# Run the reusable NERP modules together for a full prediction flow.

# %%
from nerp.ai_engine.train_model import train_prediction_model
from nerp.ai_engine.predict import predict_failure

model = train_prediction_model()
predict_failure(model, cpu=92, memory=85, latency=100)
